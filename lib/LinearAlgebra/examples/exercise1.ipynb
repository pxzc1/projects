# %% [markdown]
# ## Question: Jill designs solar panels as a hobby.
# - On April 1st, Jill's  "Mark I" design begins generating power: 1 $\text{kj/day}$.
# - On May 1st, her "Mark II" design begins generating power $\text{4 kj/day}$
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# 1. What day is it when Jill's Mark II design has generated as much total energy as the Mark I design?

# %%
markI = 30*1
markII = markI / 4

print(round(markII))
# Out:
# 8

# %% [markdown]
# This mean, it will takes **atleast 8 days** to generate as much energy as Mark I had made.
#
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# 2. How much total energy have both generated by that day?

# %%
markI = markI + (8*1)
markII = 4*8
print(markI, markII)
# Out:
# 38 32
